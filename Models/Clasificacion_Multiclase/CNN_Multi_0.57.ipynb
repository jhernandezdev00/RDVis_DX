# %%
#LIBRERIAS
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import cv2
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from tensorflow.keras import layers, models, regularizers
from keras.models import Sequential
from sklearn.metrics import confusion_matrix
import seaborn as sns
import collections

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ReduceLROnPlateau

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#retina_df = pd.read_csv("../Datos/Retina_DF_BAL.csv")
retina_df = pd.read_csv("../content/drive/MyDrive/Img_Preprocessing_v1/Retina_DF_BAL.csv")

retina_df.head(6)
# Out:
#          image  level  id_Paciente                             path  existe  \
# 0   19521_left      2        19521   ..\Datos\Train\19521_left.jpeg    True
# 1  19522_right      3        19522  ..\Datos\Train\19522_right.jpeg    True
# 2   14482_left      3        14482   ..\Datos\Train\14482_left.jpeg    True
# 3  13267_right      2        13267  ..\Datos\Train\13267_right.jpeg    True
# 4   34879_left      0        34879   ..\Datos\Train\34879_left.jpeg    True
# 5   27922_left      3        27922   ..\Datos\Train\27922_left.jpeg    True
#
#        tipo  eye
# 0  MODERADA    0
# 1    SEVERA    1
# 2    SEVERA    0
# 3  MODERADA    1
# 4     NO RD    0
# 5    SEVERA    0

# %%
retina_df.shape
# Out:
# (3500, 7)

# %%
direccion = "../content/drive/MyDrive/Img_Preprocessing_v1/"
lear_rate = 0.0005
batch_tam = 32
dimensiones = 224
num_clases = 5

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    direccion,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(dimensiones, dimensiones),
    batch_size=batch_tam)

val_ds = tf.keras.utils.image_dataset_from_directory(
    direccion,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(dimensiones, dimensiones),
    batch_size=batch_tam)
# Out:
# Found 3500 files belonging to 5 classes.
# Using 2800 files for training.
# Found 3500 files belonging to 5 classes.
# Using 700 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['LEVE', 'MODERADA', 'NO RD', 'RD PROLIFERA', 'SEVERA']

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
from tensorflow import keras

# %%
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomZoom(0.1),
    layers.RandomContrast(0.2),
])

# data_augmentation = keras.Sequential([
#     layers.RandomFlip("horizontal_and_vertical"),
#     layers.RandomZoom(0.1),
#     layers.RandomContrast(0.2),
#     layers.RandomRotation(0.2),  # Rotación aleatoria de hasta 20 grados
#     layers.RandomTranslation(height_factor=0.1, width_factor=0.1),  # Desplazamiento aleatorio
#     layers.RandomBrightness(0.2),  # Ajuste aleatorio de brillo
# ])

normalization_layer = layers.Rescaling(1./255)

# %%
train_ds = train_ds.map(lambda x, y: (data_augmentation(x, training=True), y))
#train_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow((images[i].numpy()).astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
# num_classes = 5

# model = tf.keras.Sequential([
#     tf.keras.layers.Rescaling(1./255, input_shape=(224, 224, 3)),
#     tf.keras.layers.Conv2D(32, (3,3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
#     tf.keras.layers.MaxPooling2D(),
#     tf.keras.layers.Conv2D(64, (3,3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
#     tf.keras.layers.MaxPooling2D(),
#     tf.keras.layers.Conv2D(128, (3,3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
#     tf.keras.layers.MaxPooling2D(),
#     tf.keras.layers.Flatten(),
#     tf.keras.layers.Dense(256, activation='relu'),
#     tf.keras.layers.Dropout(0.5),
#     tf.keras.layers.Dense(num_classes, activation='softmax')
# ])

num_classes = 5

# model = tf.keras.Sequential([
#     tf.keras.layers.Rescaling(1./255, input_shape=(224, 224, 3)),
#     tf.keras.layers.Conv2D(32, (3,3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
#     tf.keras.layers.MaxPooling2D(),
#     tf.keras.layers.Conv2D(64, (3,3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
#     tf.keras.layers.MaxPooling2D(),
#     tf.keras.layers.Conv2D(128, (3,3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
#     tf.keras.layers.MaxPooling2D(),
#     tf.keras.layers.Conv2D(128, (3,3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
#     tf.keras.layers.MaxPooling2D(),
#     tf.keras.layers.Flatten(),
#     tf.keras.layers.Dense(256, activation='relu'),
#     tf.keras.layers.Dropout(0.5),
#     tf.keras.layers.Dense(num_classes, activation='softmax')
# ])

base_model = tf.keras.applications.EfficientNetB0(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False  # Congelar pesos

model = tf.keras.Sequential([
    base_model,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(num_classes, activation='softmax')
])
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
history = model.fit(train_ds,
                    epochs=100,
                    callbacks=[early_stopping],
                    steps_per_epoch=len(train_ds),
                    validation_data=val_ds,
                    validation_steps=len(val_ds))
# Out:
# Epoch 1/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 933s 10s/step - accuracy: 0.2941 - loss: 1.5800 - val_accuracy: 0.4271 - val_loss: 1.3196
# Epoch 2/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 298s 3s/step - accuracy: 0.4106 - loss: 1.3535 - val_accuracy: 0.4443 - val_loss: 1.2858
# Epoch 3/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 307s 4s/step - accuracy: 0.4081 - loss: 1.3271 - val_accuracy: 0.4500 - val_loss: 1.2691
# Epoch 4/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 328s 4s/step - accuracy: 0.4370 - loss: 1.2892 - val_accuracy: 0.4600 - val_loss: 1.2508
# Epoch 5/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 290s 3s/step - accuracy: 0.4284 - loss: 1.2613 - val_accuracy: 0.4529 - val_loss: 1.2490
# Epoch 6/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 313s 4s/step - accuracy: 0.4519 - loss: 1.2409 - val_accuracy: 0.4557 - val_loss: 1.2414
# Epoch 7/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 290s 3s/step - accuracy: 0.4687 - loss: 1.2194 - val_accuracy: 0.4571 - val_loss: 1.2414
# Epoch 8/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 321s 3s/step - accuracy: 0.4667 - loss: 1.2012 - val_accuracy: 0.4600 - val_loss: 1.2331
# Epoch 9/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 309s 4s/step - accuracy: 0.4850 - loss: 1.1977 - val_accuracy: 0.4657 - val_loss: 1.2348
# Epoch 10/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 310s 4s/step - accuracy: 0.4757 - loss: 1.1928 - val_accuracy: 0.4600 - val_loss: 1.2349
# Epoch 11/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 295s 3s/step - accuracy: 0.4825 - loss: 1.1888 - val_accuracy: 0.4629 - val_loss: 1.2330
# Epoch 12/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 322s 3s/step - accuracy: 0.4662 - loss: 1.1655 - val_accuracy: 0.4329 - val_loss: 1.2311
# Epoch 13/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 320s 3s/step - accuracy: 0.4940 - loss: 1.1578 - val_accuracy: 0.4729 - val_loss: 1.2261
# Epoch 14/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 321s 3s/step - accuracy: 0.5196 - loss: 1.1321 - val_accuracy: 0.4600 - val_loss: 1.2322
# Epoch 15/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 322s 3s/step - accuracy: 0.5209 - loss: 1.1189 - val_accuracy: 0.4571 - val_loss: 1.2403
# Epoch 16/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 279s 3s/step - accuracy: 0.5233 - loss: 1.1078 - val_accuracy: 0.4643 - val_loss: 1.2286
# Epoch 17/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 309s 4s/step - accuracy: 0.5359 - loss: 1.0962 - val_accuracy: 0.4600 - val_loss: 1.2248
# Epoch 18/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 309s 4s/step - accuracy: 0.5317 - loss: 1.0908 - val_accuracy: 0.4543 - val_loss: 1.2279
# Epoch 19/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 281s 3s/step - accuracy: 0.5352 - loss: 1.0758 - val_accuracy: 0.4671 - val_loss: 1.2228
# Epoch 20/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 323s 3s/step - accuracy: 0.5638 - loss: 1.0657 - val_accuracy: 0.4643 - val_loss: 1.2295
# Epoch 21/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 309s 4s/step - accuracy: 0.5574 - loss: 1.0489 - val_accuracy: 0.4671 - val_loss: 1.2297
# Epoch 22/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 307s 3s/step - accuracy: 0.5499 - loss: 1.0531 - val_accuracy: 0.4643 - val_loss: 1.2278
# Epoch 23/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 297s 3s/step - accuracy: 0.5670 - loss: 1.0249 - val_accuracy: 0.4757 - val_loss: 1.2312
# Epoch 24/100
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 308s 4s/step - accuracy: 0.5812 - loss: 1.0153 - val_accuracy: 0.4729 - val_loss: 1.2265

# %%
# Gráfica de precisión
plt.plot(history.history['accuracy'], label='Entrenamiento')
plt.plot(history.history['val_accuracy'], label='Validación')
plt.xlabel('Épocas')
plt.ylabel('Precisión')
plt.legend()
plt.show()

# Gráfica de pérdida
plt.plot(history.history['loss'], label='Entrenamiento')
plt.plot(history.history['val_loss'], label='Validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.show()

# %%
y_pred = model.predict(val_ds)
y_ref = np.argmax(y_pred, axis=1)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 62s 3s/step

# %%
y_true = []
for images, labels in val_ds:
    y_true.extend(labels.numpy())

# %%
matriz_conf = confusion_matrix(y_ref,y_true)
plt.figure(figsize=(8, 6))
sns.heatmap(matriz_conf, annot=True, fmt='d', cmap='Blues')
plt.title("Matriz de confusión")
plt.xlabel("Etiqueta predicha")
plt.ylabel("Etiqueta real")
plt.show()

# %%
model.save('model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
model.save('model1.keras')
